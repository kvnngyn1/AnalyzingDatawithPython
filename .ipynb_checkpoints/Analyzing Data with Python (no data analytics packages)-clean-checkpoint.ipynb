# %%
import unicodecsv as csv

# %% [markdown]
# # Data Analysis Process

# %% [markdown]
# ### Step 1: Get data

# %% [markdown]
# Categorical Data - Any value that if you ran mathematical operation on, you'd get nonsensical data

# %% [markdown]
# Ordinal Data - Any value that if you ran mathematical operation on it, you'd get sensical data

# %%
# # LONG WAY
# enrollment_data = []
# file = open('./enrollments.csv', 'rb')
# data = csv.DictReader(file)
# for i in data:
#     enrollment_data.append(i)
# file.close()

# #  SHORT WAY
# with open('enrollments.csv', 'rb') as file:
#     data = csv.DictReader(file)
#     enrollment_data = list(data)

# DYNAMIC WAY
def read_from_csv(filepath):
    with open( filepath, 'rb') as file:
        data = csv.DictReader(file)
        return list(data)

# %%
enrollment_data = read_from_csv('./enrollments.csv')
engagement_data = read_from_csv('./engagements.csv')
submission_data = read_from_csv('./submissions.csv')

# %%
enrollment_data[0]
# Out:
# {'account_key': '700',
#  'status': 'canceled',
#  'join_date': '2017-11-10',
#  'cancel_date': '2017-11-16',
#  'days_to_cancel': '6',
#  'is_enrolled': 'FALSE',
#  'is_canceled': 'TRUE'}

# %%
engagement_data[0]
# Out:
# {'acct': '0',
#  'utc_date': '2018-01-09',
#  'num_courses_visited': '1',
#  'total_minutes_visited': '11.6793745',
#  'lessons_completed': '0',
#  'projects_completed': '0'}

# %%
submission_data[0]
# Out:
# {'creation_date': '2018-01-14',
#  'completion_date': '2018-01-16',
#  'assigned_rating': 'UNGRADED',
#  'account_key': '256',
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# Categorical Data - Any value that if you ran mathematical operation on, you'd get nonsensical data

# %% [markdown]
# Ordinal Data - Any value that if you ran mathematical operation on it, you'd get sensical data

# %% [markdown]
# ### Step 2: Clean Data

# %%
from datetime import datetime as dt

# %%
dt.strptime('2017-11-10', '%Y-%m-%d')
# Out:
# datetime.datetime(2017, 11, 10, 0, 0)

# %%
dt.strftime(dt(2017, 11, 10, 0, 0), '%d/%m')
# Out:
# '10/11'

# %%
def convert_to_date(date_string):
    if date_string == '':
        return None
    return dt.strptime(date_string, '%Y-%m-%d')
                    
def convert_to_int(int_string):
    if int_string == '':
        return None
    return int(int_string)
                    
def convert_to_float(float_string):
    if float_string == '':
        return None
    return float(float_string)
                    
def convert_to_bool(bool_string):
    if bool_string == '':
        return None
    elif bool_string == 'TRUE':
        return True
    elif bool_string == 'FALSE':
        return False

# %%
for r in enrollment_data:
    r['join_date'] = convert_to_date(r['join_date'])
    r['cancel_date'] = convert_to_date(r['cancel_date'])
    r['days_to_cancel'] = convert_to_int(r['days_to_cancel'])
    r['is_enrolled'] = convert_to_bool(r['is_enrolled'])
    r['is_canceled'] = convert_to_bool(r['is_canceled'])

# %%
enrollment_data[0]
# Out:
# {'account_key': '700',
#  'status': 'canceled',
#  'join_date': datetime.datetime(2017, 11, 10, 0, 0),
#  'cancel_date': datetime.datetime(2017, 11, 16, 0, 0),
#  'days_to_cancel': 6,
#  'is_enrolled': False,
#  'is_canceled': True}

# %%
for r in engagement_data:
    r['utc_date'] = convert_to_date(r['utc_date'])
    r['num_courses_visited'] = convert_to_int(r['num_courses_visited'])
    r['total_minutes_visited'] = convert_to_float(r['total_minutes_visited'])
    r['lessons_completed'] = convert_to_int(r['lessons_completed'])
    r['projects_completed'] = convert_to_int(r['projects_completed'])

# %%
engagement_data[0]
# Out:
# {'acct': '0',
#  'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#  'num_courses_visited': 1,
#  'total_minutes_visited': 11.6793745,
#  'lessons_completed': 0,
#  'projects_completed': 0}

# %%
for r in submission_data:
    r['creation_date'] = convert_to_date(r['creation_date'])
    r['completion_date'] = convert_to_date(r['completion_date'])

# %%
submission_data[0]
# Out:
# {'creation_date': datetime.datetime(2018, 1, 14, 0, 0),
#  'completion_date': datetime.datetime(2018, 1, 16, 0, 0),
#  'assigned_rating': 'UNGRADED',
#  'account_key': '256',
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %%
# RUN ONLY ONCE!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# THIS WILL DELETE ACCT AND REPLACE WITH ACCOUNT_KEY
# once done comment out to prvent that from happening

for r in engagement_data:
    r['account_key']= r['acct']
    del r['acct']

# %% [markdown]
# ### Step 3: Answer Questions with Data

# %%
# unique_engagements

print(f"Enrollment records:{ len(enrollment_data) }")
print(f"Engagement records:{ len(engagement_data) }")
print(f"Submission records:{ len(submission_data) }")
# Out:
# Enrollment records:1640
# Engagement records:136240
# Submission records:3642

# %%
def get_unique_records(dataset, column_name):
    unique_data = set()
    for r in dataset:
        unique_data.add(r[column_name])
    return unique_data

# %%
unique_enrollments = get_unique_records(enrollment_data, 'account_key')
unique_engagements = get_unique_records(engagement_data, 'account_key')
unique_submissions = get_unique_records(submission_data, 'account_key')

# %%
print(f"Unique enrollment records:{ len(unique_enrollments) }")
print(f"Unique engagement records:{ len(unique_engagements) }")
print(f"Unique submission records:{ len(unique_submissions) }")
# Out:
# Unique enrollment records:1302
# Unique engagement records:1237
# Unique submission records:743

# %%
outliers = 0
for r in enrollment_data:
    if r['account_key'] not in unique_engagements and r['join_date'] != r['cancel_date']:
        outliers+=1
        print(r, end='\n\n')
# Out:
# {'account_key': '1304', 'status': 'canceled', 'join_date': datetime.datetime(2018, 1, 10, 0, 0), 'cancel_date': datetime.datetime(2018, 3, 10, 0, 0), 'days_to_cancel': 59, 'is_enrolled': True, 'is_canceled': True}
#
# {'account_key': '1304', 'status': 'canceled', 'join_date': datetime.datetime(2018, 3, 10, 0, 0), 'cancel_date': datetime.datetime(2018, 6, 17, 0, 0), 'days_to_cancel': 99, 'is_enrolled': True, 'is_canceled': True}
#
# {'account_key': '1101', 'status': 'current', 'join_date': datetime.datetime(2018, 2, 25, 0, 0), 'cancel_date': None, 'days_to_cancel': None, 'is_enrolled': True, 'is_canceled': False}

# %%
test_accounts = set()
for r in enrollment_data:
    if r['is_enrolled']:
        test_accounts.add(r['account_key'])
print(f"{len(test_accounts)} possible test accounts found")
# Out:
# 6 possible test accounts found

# %%
test_accounts
# Out:
# {'1069', '1101', '1304', '312', '448', '818'}

# %%
# Remove all records from all datasets that have the account keys in them
def remove_test_accounts(dataset):
    records_to_remove = []
    for r in dataset:
        if r['account_key'] not in test_accounts:
            records_to_remove.append(r)
    return records_to_remove

true_enrollments = remove_test_accounts(enrollment_data)
true_engagements = remove_test_accounts(engagement_data)
true_submissions = remove_test_accounts(submission_data)

# %%
print(f"True enrollment records:{ len(true_enrollments) }")
print(f"True engagement records:{ len(true_engagements) }")
print(f"True submission records:{ len(true_submissions) }")
# Out:
# True enrollment records:1622
# True engagement records:135656
# True submission records:3634

# %% [markdown]
# <h4>Find quality accounts in which:</h4>
# <ol>
#     <li>The account is currently active i.e. is_canceled is False</li>
#     <li>days_to_cancel is greater than 7 i.e. the trial period</li>
#     <li>The latest vald record for each particular VALID user</li>
# </ol>

# %%
true_enrollments[0]
# Out:
# {'account_key': '700',
#  'status': 'canceled',
#  'join_date': datetime.datetime(2017, 11, 10, 0, 0),
#  'cancel_date': datetime.datetime(2017, 11, 16, 0, 0),
#  'days_to_cancel': 6,
#  'is_enrolled': False,
#  'is_canceled': True}

# %%
# {
#     "123": datetime(),
#     "456": datetime(),
#     "789": datetime()
# }

accounts_in_good_standing = dict()
for r in true_enrollments:
    # if the account is currently active
    if r['days_to_cancel'] is not None and r['cancel_date'] is not None:
        # if days_to_cancel is greater than the 7-day trial period
        if not r['is_canceled'] or r['days_to_cancel'] > 7:
            # if record has the most recent join_date
            if r['account_key'] not in accounts_in_good_standing or r['join_date'] > accounts_in_good_standing[r['account_key']]:
                accounts_in_good_standing[r['account_key']] = r['join_date']

# %%
len(accounts_in_good_standing)
# Out:
# 445

# %%
accounts_in_good_standing
# Out:
# {'429': datetime.datetime(2018, 3, 10, 0, 0),
#  '60': datetime.datetime(2018, 1, 14, 0, 0),
#  '322': datetime.datetime(2018, 2, 12, 0, 0),
#  '584': datetime.datetime(2018, 1, 14, 0, 0),
#  '458': datetime.datetime(2017, 11, 10, 0, 0),
#  '1058': datetime.datetime(2018, 1, 14, 0, 0),
#  '45': datetime.datetime(2017, 11, 10, 0, 0),
#  '315': datetime.datetime(2017, 11, 10, 0, 0),
#  '408': datetime.datetime(2018, 4, 1, 0, 0),
#  '51': datetime.datetime(2018, 3, 10, 0, 0),
#  '323': datetime.datetime(2017, 11, 10, 0, 0),
#  '130': datetime.datetime(2018, 4, 1, 0, 0),
#  '550': datetime.datetime(2018, 5, 28, 0, 0),
#  '44': datetime.datetime(2017, 11, 10, 0, 0),
#  '440': datetime.datetime(2017, 11, 11, 0, 0),
#  '57': datetime.datetime(2017, 11, 11, 0, 0),
#  '1090': datetime.datetime(2017, 11, 11, 0, 0),
#  '541': datetime.datetime(2017, 11, 12, 0, 0),
#  '756': datetime.datetime(2017, 11, 15, 0, 0),
#  '101': datetime.datetime(2017, 11, 12, 0, 0),
#  '800': datetime.datetime(2018, 3, 4, 0, 0),
#  '702': datetime.datetime(2018, 1, 14, 0, 0),
#  '744': datetime.datetime(2017, 11, 14, 0, 0),
#  '217': datetime.datetime(2017, 11, 15, 0, 0),
#  '1211': datetime.datetime(2017, 11, 15, 0, 0),
#  '53': datetime.datetime(2017, 11, 14, 0, 0),
#  '338': datetime.datetime(2018, 2, 3, 0, 0),
#  '253': datetime.datetime(2017, 11, 16, 0, 0),
#  '178': datetime.datetime(2017, 11, 17, 0, 0),
#  '822': datetime.datetime(2017, 11, 17, 0, 0),
#  '123': datetime.datetime(2018, 3, 10, 0, 0),
#  '1204': datetime.datetime(2017, 11, 10, 0, 0),
#  '394': datetime.datetime(2017, 11, 10, 0, 0),
#  '1253': datetime.datetime(2017, 11, 10, 0, 0),
#  '504': datetime.datetime(2017, 11, 10, 0, 0),
#  '72': datetime.datetime(2017, 11, 10, 0, 0),
#  '268': datetime.datetime(2018, 4, 3, 0, 0),
#  '339': datetime.datetime(2018, 4, 1, 0, 0),
#  '1244': datetime.datetime(2018, 5, 17, 0, 0),
#  '752': datetime.datetime(2017, 11, 10, 0, 0),
#  '520': datetime.datetime(2017, 11, 10, 0, 0),
#  '367': datetime.datetime(2017, 11, 11, 0, 0),
#  '258': datetime.datetime(2017, 11, 10, 0, 0),
#  '329': datetime.datetime(2018, 3, 10, 0, 0),
#  '612': datetime.datetime(2017, 11, 10, 0, 0),
#  '150': datetime.datetime(2017, 11, 10, 0, 0),
#  '179': datetime.datetime(2017, 11, 10, 0, 0),
#  '587': datetime.datetime(2018, 1, 14, 0, 0),
#  '439': datetime.datetime(2017, 11, 10, 0, 0),
#  '18': datetime.datetime(2017, 11, 10, 0, 0),
#  '544': datetime.datetime(2017, 11, 10, 0, 0),
#  '913': datetime.datetime(2018, 1, 14, 0, 0),
#  '576': datetime.datetime(2017, 11, 10, 0, 0),
#  '431': datetime.datetime(2017, 11, 10, 0, 0),
#  '480': datetime.datetime(2018, 3, 10, 0, 0),
#  '525': datetime.datetime(2017, 11, 10, 0, 0),
#  '1111': datetime.datetime(2018, 4, 1, 0, 0),
#  '1107': datetime.datetime(2017, 11, 11, 0, 0),
#  '577': datetime.datetime(2018, 2, 5, 0, 0),
#  '92': datetime.datetime(2017, 11, 12, 0, 0),
#  '335': datetime.datetime(2017, 11, 12, 0, 0),
#  '693': datetime.datetime(2018, 1, 14, 0, 0),
#  '88': datetime.datetime(2018, 3, 10, 0, 0),
#  '983': datetime.datetime(2018, 1, 14, 0, 0),
#  '1118': datetime.datetime(2017, 11, 17, 0, 0),
#  '499': datetime.datetime(2018, 2, 6, 0, 0),
#  '590': datetime.datetime(2018, 2, 3, 0, 0),
#  '264': datetime.datetime(2018, 2, 3, 0, 0),
#  '1130': datetime.datetime(2017, 12, 3, 0, 0),
#  '736': datetime.datetime(2017, 12, 4, 0, 0),
#  '976': datetime.datetime(2017, 12, 4, 0, 0),
#  '316': datetime.datetime(2017, 12, 6, 0, 0),
#  '347': datetime.datetime(2017, 12, 7, 0, 0),
#  '343': datetime.datetime(2017, 12, 7, 0, 0),
#  '221': datetime.datetime(2017, 12, 3, 0, 0),
#  '631': datetime.datetime(2018, 5, 8, 0, 0),
#  '1009': datetime.datetime(2017, 12, 5, 0, 0),
#  '909': datetime.datetime(2017, 12, 5, 0, 0),
#  '524': datetime.datetime(2017, 12, 6, 0, 0),
#  '759': datetime.datetime(2018, 2, 3, 0, 0),
#  '896': datetime.datetime(2018, 3, 10, 0, 0),
#  '411': datetime.datetime(2018, 4, 8, 0, 0),
#  '705': datetime.datetime(2018, 4, 8, 0, 0),
#  '776': datetime.datetime(2017, 12, 8, 0, 0),
#  '557': datetime.datetime(2018, 2, 3, 0, 0),
#  '634': datetime.datetime(2017, 12, 9, 0, 0),
#  '1124': datetime.datetime(2018, 2, 3, 0, 0),
#  '932': datetime.datetime(2017, 12, 9, 0, 0),
#  '169': datetime.datetime(2018, 2, 5, 0, 0),
#  '229': datetime.datetime(2018, 1, 7, 0, 0),
#  '622': datetime.datetime(2018, 1, 8, 0, 0),
#  '730': datetime.datetime(2018, 1, 8, 0, 0),
#  '905': datetime.datetime(2018, 1, 8, 0, 0),
#  '170': datetime.datetime(2018, 1, 9, 0, 0),
#  '467': datetime.datetime(2018, 1, 10, 0, 0),
#  '780': datetime.datetime(2018, 1, 11, 0, 0),
#  '418': datetime.datetime(2018, 1, 11, 0, 0),
#  '1074': datetime.datetime(2018, 3, 10, 0, 0),
#  '859': datetime.datetime(2018, 1, 11, 0, 0),
#  '91': datetime.datetime(2017, 11, 10, 0, 0),
#  '3': datetime.datetime(2017, 11, 10, 0, 0),
#  '157': datetime.datetime(2018, 3, 10, 0, 0),
#  '378': datetime.datetime(2018, 3, 10, 0, 0),
#  '1214': datetime.datetime(2017, 11, 10, 0, 0),
#  '483': datetime.datetime(2017, 11, 10, 0, 0),
#  '1094': datetime.datetime(2017, 11, 10, 0, 0),
#  '882': datetime.datetime(2017, 11, 10, 0, 0),
#  '412': datetime.datetime(2018, 3, 10, 0, 0),
#  '366': datetime.datetime(2018, 4, 1, 0, 0),
#  '696': datetime.datetime(2017, 11, 10, 0, 0),
#  '1142': datetime.datetime(2018, 3, 10, 0, 0),
#  '148': datetime.datetime(2018, 4, 1, 0, 0),
#  '630': datetime.datetime(2017, 11, 11, 0, 0),
#  '1011': datetime.datetime(2018, 4, 8, 0, 0),
#  '161': datetime.datetime(2017, 11, 12, 0, 0),
#  '441': datetime.datetime(2017, 11, 12, 0, 0),
#  '712': datetime.datetime(2017, 11, 13, 0, 0),
#  '76': datetime.datetime(2017, 11, 15, 0, 0),
#  '938': datetime.datetime(2017, 11, 14, 0, 0),
#  '829': datetime.datetime(2017, 11, 15, 0, 0),
#  '203': datetime.datetime(2018, 5, 12, 0, 0),
#  '563': datetime.datetime(2017, 12, 3, 0, 0),
#  '1167': datetime.datetime(2017, 12, 3, 0, 0),
#  '643': datetime.datetime(2018, 4, 8, 0, 0),
#  '110': datetime.datetime(2017, 12, 3, 0, 0),
#  '1289': datetime.datetime(2017, 12, 4, 0, 0),
#  '500': datetime.datetime(2017, 12, 5, 0, 0),
#  '1160': datetime.datetime(2017, 12, 5, 0, 0),
#  '64': datetime.datetime(2017, 12, 6, 0, 0),
#  '637': datetime.datetime(2018, 5, 6, 0, 0),
#  '52': datetime.datetime(2017, 12, 7, 0, 0),
#  '111': datetime.datetime(2017, 12, 7, 0, 0),
#  '583': datetime.datetime(2017, 12, 8, 0, 0),
#  '1199': datetime.datetime(2017, 12, 8, 0, 0),
#  '743': datetime.datetime(2017, 12, 9, 0, 0),
#  '474': datetime.datetime(2017, 12, 9, 0, 0),
#  '667': datetime.datetime(2017, 12, 9, 0, 0),
#  '1095': datetime.datetime(2018, 6, 6, 0, 0),
#  '79': datetime.datetime(2017, 12, 9, 0, 0),
#  '197': datetime.datetime(2018, 1, 7, 0, 0),
#  '67': datetime.datetime(2018, 1, 7, 0, 0),
#  '678': datetime.datetime(2018, 1, 8, 0, 0),
#  '873': datetime.datetime(2018, 1, 8, 0, 0),
#  '623': datetime.datetime(2018, 1, 8, 0, 0),
#  '507': datetime.datetime(2018, 1, 9, 0, 0),
#  '270': datetime.datetime(2018, 1, 9, 0, 0),
#  '362': datetime.datetime(2018, 2, 5, 0, 0),
#  '263': datetime.datetime(2018, 6, 1, 0, 0),
#  '965': datetime.datetime(2018, 1, 10, 0, 0),
#  '761': datetime.datetime(2018, 1, 11, 0, 0),
#  '785': datetime.datetime(2018, 4, 8, 0, 0),
#  '989': datetime.datetime(2018, 4, 8, 0, 0),
#  '682': datetime.datetime(2018, 4, 8, 0, 0),
#  '671': datetime.datetime(2017, 12, 9, 0, 0),
#  '1121': datetime.datetime(2018, 1, 12, 0, 0),
#  '966': datetime.datetime(2018, 1, 7, 0, 0),
#  '442': datetime.datetime(2018, 3, 15, 0, 0),
#  '5': datetime.datetime(2018, 1, 7, 0, 0),
#  '34': datetime.datetime(2018, 1, 8, 0, 0),
#  '824': datetime.datetime(2018, 2, 10, 0, 0),
#  '1060': datetime.datetime(2018, 1, 11, 0, 0),
#  '227': datetime.datetime(2017, 11, 12, 0, 0),
#  '599': datetime.datetime(2018, 1, 14, 0, 0),
#  '181': datetime.datetime(2017, 11, 13, 0, 0),
#  '639': datetime.datetime(2017, 11, 13, 0, 0),
#  '1303': datetime.datetime(2018, 4, 8, 0, 0),
#  '969': datetime.datetime(2017, 11, 14, 0, 0),
#  '972': datetime.datetime(2018, 3, 10, 0, 0),
#  '334': datetime.datetime(2017, 11, 16, 0, 0),
#  '1277': datetime.datetime(2018, 1, 14, 0, 0),
#  '1071': datetime.datetime(2018, 1, 14, 0, 0),
#  '923': datetime.datetime(2018, 1, 14, 0, 0),
#  '640': datetime.datetime(2018, 3, 10, 0, 0),
#  '1174': datetime.datetime(2018, 2, 3, 0, 0),
#  '1019': datetime.datetime(2017, 11, 11, 0, 0),
#  '655': datetime.datetime(2017, 11, 10, 0, 0),
#  '529': datetime.datetime(2017, 12, 8, 0, 0),
#  '256': datetime.datetime(2018, 4, 1, 0, 0),
#  '523': datetime.datetime(2018, 1, 12, 0, 0),
#  '24': datetime.datetime(2017, 12, 3, 0, 0),
#  '397': datetime.datetime(2017, 12, 4, 0, 0),
#  '265': datetime.datetime(2017, 12, 4, 0, 0),
#  '650': datetime.datetime(2018, 3, 4, 0, 0),
#  '1013': datetime.datetime(2018, 4, 1, 0, 0),
#  '618': datetime.datetime(2017, 12, 5, 0, 0),
#  '1236': datetime.datetime(2017, 12, 5, 0, 0),
#  '866': datetime.datetime(2017, 12, 7, 0, 0),
#  '1201': datetime.datetime(2017, 12, 7, 0, 0),
#  '193': datetime.datetime(2017, 12, 8, 0, 0),
#  '710': datetime.datetime(2018, 2, 3, 0, 0),
#  '180': datetime.datetime(2018, 3, 10, 0, 0),
#  '722': datetime.datetime(2018, 3, 10, 0, 0),
#  '954': datetime.datetime(2018, 3, 10, 0, 0),
#  '140': datetime.datetime(2017, 11, 10, 0, 0),
#  '1139': datetime.datetime(2018, 1, 16, 0, 0),
#  '388': datetime.datetime(2017, 12, 8, 0, 0),
#  '147': datetime.datetime(2017, 12, 3, 0, 0),
#  '119': datetime.datetime(2018, 2, 3, 0, 0),
#  '97': datetime.datetime(2018, 2, 5, 0, 0),
#  '984': datetime.datetime(2018, 2, 5, 0, 0),
#  '444': datetime.datetime(2018, 2, 5, 0, 0),
#  '386': datetime.datetime(2018, 4, 8, 0, 0),
#  '649': datetime.datetime(2017, 11, 10, 0, 0),
#  '165': datetime.datetime(2017, 11, 10, 0, 0),
#  '580': datetime.datetime(2017, 11, 10, 0, 0),
#  '919': datetime.datetime(2017, 11, 10, 0, 0),
#  '90': datetime.datetime(2018, 3, 10, 0, 0),
#  '864': datetime.datetime(2017, 11, 10, 0, 0),
#  '626': datetime.datetime(2018, 3, 4, 0, 0),
#  '1117': datetime.datetime(2017, 11, 11, 0, 0),
#  '187': datetime.datetime(2017, 11, 12, 0, 0),
#  '547': datetime.datetime(2018, 2, 3, 0, 0),
#  '159': datetime.datetime(2017, 12, 9, 0, 0),
#  '1226': datetime.datetime(2018, 4, 8, 0, 0),
#  '857': datetime.datetime(2018, 2, 6, 0, 0),
#  '143': datetime.datetime(2018, 2, 9, 0, 0),
#  '138': datetime.datetime(2018, 2, 10, 0, 0),
#  '952': datetime.datetime(2018, 2, 11, 0, 0),
#  '416': datetime.datetime(2018, 4, 8, 0, 0),
#  '477': datetime.datetime(2018, 3, 4, 0, 0),
#  '132': datetime.datetime(2018, 3, 4, 0, 0),
#  '624': datetime.datetime(2018, 3, 4, 0, 0),
#  '1247': datetime.datetime(2018, 3, 5, 0, 0),
#  '251': datetime.datetime(2018, 2, 6, 0, 0),
#  '709': datetime.datetime(2018, 2, 8, 0, 0),
#  '564': datetime.datetime(2018, 2, 8, 0, 0),
#  '792': datetime.datetime(2018, 2, 9, 0, 0),
#  '833': datetime.datetime(2018, 2, 9, 0, 0),
#  '823': datetime.datetime(2018, 4, 8, 0, 0),
#  '348': datetime.datetime(2018, 2, 5, 0, 0),
#  '185': datetime.datetime(2018, 3, 10, 0, 0),
#  '855': datetime.datetime(2017, 11, 14, 0, 0),
#  '191': datetime.datetime(2017, 11, 16, 0, 0),
#  '261': datetime.datetime(2017, 11, 16, 0, 0),
#  '415': datetime.datetime(2017, 11, 16, 0, 0),
#  '868': datetime.datetime(2017, 11, 16, 0, 0),
#  '719': datetime.datetime(2017, 11, 17, 0, 0),
#  '836': datetime.datetime(2017, 12, 9, 0, 0),
#  '108': datetime.datetime(2018, 4, 20, 0, 0),
#  '285': datetime.datetime(2018, 1, 7, 0, 0),
#  '698': datetime.datetime(2018, 1, 8, 0, 0),
#  '427': datetime.datetime(2018, 1, 9, 0, 0),
#  '1212': datetime.datetime(2018, 7, 19, 0, 0),
#  '1140': datetime.datetime(2018, 1, 10, 0, 0),
#  '505': datetime.datetime(2018, 3, 7, 0, 0),
#  '171': datetime.datetime(2018, 3, 8, 0, 0),
#  '1102': datetime.datetime(2018, 4, 8, 0, 0),
#  '1287': datetime.datetime(2018, 3, 10, 0, 0),
#  '1254': datetime.datetime(2018, 1, 10, 0, 0),
#  '1259': datetime.datetime(2018, 1, 13, 0, 0),
#  '1128': datetime.datetime(2018, 3, 11, 0, 0),
#  '78': datetime.datetime(2017, 12, 8, 0, 0),
#  '558': datetime.datetime(2017, 12, 3, 0, 0),
#  '153': datetime.datetime(2018, 4, 1, 0, 0),
#  '473': datetime.datetime(2018, 4, 1, 0, 0),
#  '106': datetime.datetime(2017, 11, 11, 0, 0),
#  '74': datetime.datetime(2018, 4, 1, 0, 0),
#  '591': datetime.datetime(2018, 3, 10, 0, 0),
#  '419': datetime.datetime(2018, 3, 10, 0, 0),
#  '31': datetime.datetime(2017, 11, 10, 0, 0),
#  '69': datetime.datetime(2018, 3, 10, 0, 0),
#  '906': datetime.datetime(2017, 11, 17, 0, 0),
#  '601': datetime.datetime(2017, 11, 10, 0, 0),
#  '321': datetime.datetime(2018, 3, 10, 0, 0),
#  '99': datetime.datetime(2018, 3, 10, 0, 0),
#  '1103': datetime.datetime(2018, 3, 10, 0, 0),
#  '1066': datetime.datetime(2018, 3, 10, 0, 0),
#  '571': datetime.datetime(2017, 12, 8, 0, 0),
#  '426': datetime.datetime(2018, 5, 7, 0, 0),
#  '98': datetime.datetime(2018, 4, 2, 0, 0),
#  '757': datetime.datetime(2018, 1, 11, 0, 0),
#  '151': datetime.datetime(2018, 1, 11, 0, 0),
#  '534': datetime.datetime(2018, 1, 12, 0, 0),
#  '597': datetime.datetime(2018, 1, 12, 0, 0),
#  '1242': datetime.datetime(2018, 1, 12, 0, 0),
#  '732': datetime.datetime(2018, 1, 12, 0, 0),
#  '168': datetime.datetime(2018, 2, 5, 0, 0),
#  '657': datetime.datetime(2018, 3, 10, 0, 0),
#  '831': datetime.datetime(2017, 12, 3, 0, 0),
#  '1015': datetime.datetime(2017, 12, 3, 0, 0),
#  '611': datetime.datetime(2017, 12, 8, 0, 0),
#  '62': datetime.datetime(2017, 12, 8, 0, 0),
#  '697': datetime.datetime(2017, 12, 8, 0, 0),
#  '43': datetime.datetime(2017, 12, 8, 0, 0),
#  '769': datetime.datetime(2018, 4, 3, 0, 0),
#  '1123': datetime.datetime(2018, 4, 3, 0, 0),
#  '918': datetime.datetime(2018, 4, 6, 0, 0),
#  '1248': datetime.datetime(2018, 4, 6, 0, 0),
#  '1189': datetime.datetime(2018, 4, 7, 0, 0),
#  '1285': datetime.datetime(2018, 4, 7, 0, 0),
#  '844': datetime.datetime(2018, 4, 7, 0, 0),
#  '690': datetime.datetime(2018, 2, 5, 0, 0),
#  '641': datetime.datetime(2018, 4, 7, 0, 0),
#  '404': datetime.datetime(2018, 4, 8, 0, 0),
#  '105': datetime.datetime(2018, 4, 7, 0, 0),
#  '1299': datetime.datetime(2018, 2, 5, 0, 0),
#  '589': datetime.datetime(2018, 2, 5, 0, 0),
#  '793': datetime.datetime(2018, 4, 8, 0, 0),
#  '243': datetime.datetime(2017, 11, 16, 0, 0),
#  '1163': datetime.datetime(2018, 5, 6, 0, 0),
#  '948': datetime.datetime(2018, 5, 6, 0, 0),
#  '1202': datetime.datetime(2018, 5, 7, 0, 0),
#  '867': datetime.datetime(2017, 12, 9, 0, 0),
#  '1292': datetime.datetime(2018, 1, 7, 0, 0),
#  '93': datetime.datetime(2018, 1, 7, 0, 0),
#  '460': datetime.datetime(2018, 1, 7, 0, 0),
#  '610': datetime.datetime(2018, 1, 7, 0, 0),
#  '670': datetime.datetime(2018, 1, 8, 0, 0),
#  '900': datetime.datetime(2018, 1, 10, 0, 0),
#  '1053': datetime.datetime(2018, 1, 11, 0, 0),
#  '934': datetime.datetime(2018, 1, 11, 0, 0),
#  '746': datetime.datetime(2018, 2, 5, 0, 0),
#  '279': datetime.datetime(2018, 2, 5, 0, 0),
#  '136': datetime.datetime(2018, 2, 5, 0, 0),
#  '1042': datetime.datetime(2018, 5, 28, 0, 0),
#  '413': datetime.datetime(2018, 2, 6, 0, 0),
#  '306': datetime.datetime(2018, 2, 8, 0, 0),
#  '284': datetime.datetime(2018, 2, 9, 0, 0),
#  '521': datetime.datetime(2018, 4, 8, 0, 0),
#  '1049': datetime.datetime(2018, 2, 10, 0, 0),
#  '1198': datetime.datetime(2018, 3, 4, 0, 0),
#  '720': datetime.datetime(2018, 3, 4, 0, 0),
#  '958': datetime.datetime(2018, 3, 4, 0, 0),
#  '718': datetime.datetime(2018, 5, 8, 0, 0),
#  '293': datetime.datetime(2018, 5, 10, 0, 0),
#  '858': datetime.datetime(2018, 5, 12, 0, 0),
#  '713': datetime.datetime(2018, 5, 12, 0, 0),
#  '1040': datetime.datetime(2018, 5, 12, 0, 0),
#  '1305': datetime.datetime(2018, 5, 12, 0, 0),
#  '25': datetime.datetime(2017, 11, 11, 0, 0),
#  '988': datetime.datetime(2018, 5, 13, 0, 0),
#  '877': datetime.datetime(2018, 5, 13, 0, 0),
#  '42': datetime.datetime(2018, 3, 4, 0, 0),
#  '704': datetime.datetime(2018, 5, 6, 0, 0),
#  '407': datetime.datetime(2018, 5, 6, 0, 0),
#  '1029': datetime.datetime(2018, 5, 12, 0, 0),
#  '465': datetime.datetime(2018, 2, 5, 0, 0),
#  '208': datetime.datetime(2018, 3, 8, 0, 0),
#  '1260': datetime.datetime(2018, 3, 11, 0, 0),
#  '1194': datetime.datetime(2018, 3, 11, 0, 0),
#  '361': datetime.datetime(2018, 5, 13, 0, 0),
#  '220': datetime.datetime(2018, 4, 7, 0, 0),
#  '1266': datetime.datetime(2018, 6, 7, 0, 0),
#  '735': datetime.datetime(2018, 4, 14, 0, 0),
#  '1183': datetime.datetime(2018, 7, 17, 0, 0),
#  '804': datetime.datetime(2018, 6, 9, 0, 0),
#  '1208': datetime.datetime(2018, 2, 5, 0, 0),
#  '1207': datetime.datetime(2018, 2, 6, 0, 0),
#  '602': datetime.datetime(2018, 2, 6, 0, 0),
#  '1153': datetime.datetime(2018, 2, 6, 0, 0),
#  '1210': datetime.datetime(2018, 2, 7, 0, 0),
#  '916': datetime.datetime(2018, 2, 8, 0, 0),
#  '666': datetime.datetime(2018, 2, 9, 0, 0),
#  '753': datetime.datetime(2018, 3, 5, 0, 0),
#  '141': datetime.datetime(2018, 3, 7, 0, 0),
#  '729': datetime.datetime(2018, 4, 3, 0, 0),
#  '1089': datetime.datetime(2018, 4, 6, 0, 0),
#  '651': datetime.datetime(2018, 4, 6, 0, 0),
#  '1054': datetime.datetime(2018, 4, 7, 0, 0),
#  '289': datetime.datetime(2018, 4, 7, 0, 0),
#  '796': datetime.datetime(2018, 4, 7, 0, 0),
#  '1205': datetime.datetime(2018, 7, 17, 0, 0),
#  '856': datetime.datetime(2018, 7, 18, 0, 0),
#  '786': datetime.datetime(2018, 4, 2, 0, 0),
#  '1264': datetime.datetime(2018, 4, 2, 0, 0),
#  '1088': datetime.datetime(2018, 4, 3, 0, 0),
#  '811': datetime.datetime(2018, 5, 6, 0, 0),
#  '825': datetime.datetime(2018, 5, 9, 0, 0),
#  '1055': datetime.datetime(2018, 5, 8, 0, 0),
#  '1215': datetime.datetime(2018, 5, 11, 0, 0),
#  '1030': datetime.datetime(2018, 5, 11, 0, 0),
#  '955': datetime.datetime(2018, 5, 11, 0, 0),
#  '142': datetime.datetime(2018, 1, 12, 0, 0),
#  '1038': datetime.datetime(2018, 4, 4, 0, 0),
#  '1170': datetime.datetime(2018, 4, 5, 0, 0),
#  '1268': datetime.datetime(2018, 4, 6, 0, 0),
#  '706': datetime.datetime(2018, 4, 7, 0, 0),
#  '606': datetime.datetime(2018, 4, 8, 0, 0),
#  '669': datetime.datetime(2018, 5, 12, 0, 0),
#  '569': datetime.datetime(2018, 6, 2, 0, 0),
#  '912': datetime.datetime(2018, 6, 6, 0, 0),
#  '1062': datetime.datetime(2018, 5, 10, 0, 0),
#  '956': datetime.datetime(2018, 6, 8, 0, 0),
#  '777': datetime.datetime(2018, 6, 8, 0, 0),
#  '402': datetime.datetime(2018, 1, 12, 0, 0),
#  '15': datetime.datetime(2018, 3, 4, 0, 0),
#  '134': datetime.datetime(2018, 2, 5, 0, 0),
#  '1033': datetime.datetime(2018, 2, 6, 0, 0),
#  '512': datetime.datetime(2017, 11, 10, 0, 0),
#  '1243': datetime.datetime(2017, 11, 10, 0, 0),
#  '1220': datetime.datetime(2017, 11, 10, 0, 0),
#  '85': datetime.datetime(2017, 11, 11, 0, 0),
#  '160': datetime.datetime(2017, 11, 11, 0, 0),
#  '636': datetime.datetime(2018, 3, 5, 0, 0),
#  '423': datetime.datetime(2018, 2, 9, 0, 0),
#  '190': datetime.datetime(2018, 2, 11, 0, 0),
#  '692': datetime.datetime(2018, 2, 11, 0, 0),
#  '259': datetime.datetime(2018, 4, 7, 0, 0),
#  '839': datetime.datetime(2017, 11, 13, 0, 0),
#  '1161': datetime.datetime(2017, 11, 13, 0, 0),
#  '1146': datetime.datetime(2017, 11, 16, 0, 0),
#  '65': datetime.datetime(2017, 11, 16, 0, 0),
#  '787': datetime.datetime(2017, 11, 16, 0, 0),
#  '941': datetime.datetime(2018, 3, 10, 0, 0),
#  '985': datetime.datetime(2018, 3, 11, 0, 0),
#  '835': datetime.datetime(2017, 12, 3, 0, 0),
#  '549': datetime.datetime(2017, 12, 3, 0, 0),
#  '660': datetime.datetime(2017, 12, 3, 0, 0),
#  '174': datetime.datetime(2017, 12, 3, 0, 0),
#  '514': datetime.datetime(2017, 12, 4, 0, 0),
#  '778': datetime.datetime(2017, 12, 7, 0, 0),
#  '801': datetime.datetime(2017, 12, 8, 0, 0),
#  '1077': datetime.datetime(2017, 12, 8, 0, 0),
#  '808': datetime.datetime(2017, 12, 8, 0, 0),
#  '528': datetime.datetime(2018, 4, 3, 0, 0),
#  '1115': datetime.datetime(2018, 4, 8, 0, 0),
#  '447': datetime.datetime(2018, 4, 24, 0, 0),
#  '272': datetime.datetime(2018, 1, 8, 0, 0),
#  '434': datetime.datetime(2018, 1, 12, 0, 0),
#  '532': datetime.datetime(2018, 1, 12, 0, 0),
#  '937': datetime.datetime(2018, 5, 6, 0, 0),
#  '927': datetime.datetime(2018, 5, 13, 0, 0),
#  '1022': datetime.datetime(2018, 5, 7, 0, 0),
#  '410': datetime.datetime(2018, 5, 12, 0, 0),
#  '1007': datetime.datetime(2018, 5, 12, 0, 0),
#  '645': datetime.datetime(2018, 2, 9, 0, 0),
#  '1217': datetime.datetime(2018, 6, 6, 0, 0),
#  '762': datetime.datetime(2018, 6, 8, 0, 0),
#  '897': datetime.datetime(2018, 6, 8, 0, 0),
#  '1075': datetime.datetime(2018, 6, 9, 0, 0),
#  '1188': datetime.datetime(2018, 2, 10, 0, 0),
#  '1200': datetime.datetime(2018, 3, 4, 0, 0),
#  '113': datetime.datetime(2018, 3, 4, 0, 0),
#  '1082': datetime.datetime(2018, 3, 6, 0, 0),
#  '828': datetime.datetime(2018, 3, 9, 0, 0),
#  '1175': datetime.datetime(2018, 4, 2, 0, 0),
#  '19': datetime.datetime(2018, 4, 6, 0, 0),
#  '726': datetime.datetime(2018, 4, 8, 0, 0),
#  '779': datetime.datetime(2018, 5, 10, 0, 0),
#  '1249': datetime.datetime(2018, 5, 11, 0, 0),
#  '1099': datetime.datetime(2018, 5, 11, 0, 0),
#  '846': datetime.datetime(2018, 5, 12, 0, 0),
#  '1052': datetime.datetime(2018, 5, 12, 0, 0),
#  '661': datetime.datetime(2018, 5, 12, 0, 0),
#  '1178': datetime.datetime(2018, 7, 16, 0, 0)}

# %%
# remove all records that had free trials
def remove_free_trials(dataset):
    free_trials_list = []
    for r in dataset:
        if r['account_key'] in accounts_in_good_standing:
            free_trials_list.append(r)
    return free_trials_list

# %%
quality_enrollments = remove_free_trials(true_enrollments)
quality_engagements = remove_free_trials(true_engagements)
quality_submissions = remove_free_trials(true_submissions)

# %%
print(f"Quality enrollment records: {len(quality_enrollments)}")
print(f"Quality engagement records: {len(quality_engagements)}")
print(f"Quality submission records: {len(quality_submissions)}")
# Out:
# Quality enrollment records: 719
# Quality engagement records: 55675
# Quality submission records: 1110

# %%
# How many students were active on website within the first week?
def engagements_within_first_week(date_joined, date_of_first_engagement):
    time_difference = date_of_first_engagement - date_joined
    if time_difference.days >= 0 and time_difference.days < 8:
        return True

for r in quality_engagements:
    if r['num_courses_visited'] > 0:
        r['has_visited'] = 1
    else:
        r['has_visited'] = 0

first_week_engagements = list()
for r in quality_engagements:
    if engagements_within_first_week(accounts_in_good_standing[r['account_key']], r['utc_date']):
        first_week_engagements.append(r)

# %%
print(f"{len(first_week_engagements)} engagements within the first week.")
# Out:
# 3559 engagements within the first week.

# %%
# How many minutes did each student spend online in the first week?
from collections import defaultdict

def compare(dataset, a_key):
    new_data = defaultdict(list)
    for r in dataset:
        account_key = r[a_key]
        new_data[account_key].append(r)
    return new_data

engagements_grouped_by_account = compare(first_week_engagements, 'account_key')

# %%
engagements_grouped_by_account
# Out:
# defaultdict(list,
#             {'3': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 136.1835995,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 11.0550435,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 34.615231,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 406.3332692,
#                'lessons_completed': 3,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 91.475528,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 148.2441033,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 195.6512002,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1}],
#              '5': [{'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 59.72671883,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 103.5686138,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 80.18189033,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 36.24653467,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 50.034099,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 41.06708733,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1}],
#              '15': [{'utc_date': datetime.datetime(2018, 3, 4, 0, 0),
#                'num_courses_visited': 4,
#                'total_minutes_visited': 172.7098973,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 5, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 108.6473307,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 6, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 128.4392857,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 186.4863837,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 387.092143,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 87.75029717,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1}],
#              '18': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 87.14431633,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 33.370874,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 16.51477317,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 18.106194,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0}],
#              '19': [{'utc_date': datetime.datetime(2018, 4, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0}],
#              '24': [{'utc_date': datetime.datetime(2017, 12, 3, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 4, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 5, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 217.7074397,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 284.554388,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 440.9262895,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 0}],
#              '25': [{'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0}],
#              '31': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 108.8773418,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 68.14879717,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 65.06732917,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 5.1821115,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0}],
#              '34': [{'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 138.1789523,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0}],
#              '42': [{'utc_date': datetime.datetime(2018, 3, 4, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 5, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 21.85896967,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 36.51313633,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 8, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 115.934937,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0}],
#              '43': [{'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 79.710734,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 9.111304,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0}],
#              '44': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 147.2186897,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 12.43652333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 344.8648443,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 32.2591195,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 194.944491,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 1}],
#              '45': [{'utc_date': datetime.datetime(2017, 11, 10, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 101.659173,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 3,
#                'total_minutes_visited': 283.8947265,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 315.3637113,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 34.75773583,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 235.4304122,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 8.639657833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1}],
#              '51': [{'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0}],
#              '52': [{'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 3.227523833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0}],
#              '53': [{'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 25.8814905,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 17.65702567,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0}],
#              '57': [{'utc_date': datetime.datetime(2017, 11, 11, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 62.3578725,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 2.678934833,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 49.17681517,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 14, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 64.5438425,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 36.440709,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 16, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 199.1518945,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 56.97291283,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 3,
#                'total_minutes_visited': 279.5711662,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1}],
#              '60': [{'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0}],
#              '62': [{'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 136.1281002,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 157.255022,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0}],
#              '64': [{'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 27.29176333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 135.03497,
#                'lessons_completed': 3,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 109.9923932,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
# ...
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0}],
#              '1287': [{'utc_date': datetime.datetime(2018, 3, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0}],
#              '1289': [{'utc_date': datetime.datetime(2017, 12, 4, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 5.456283333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 5, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 6, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0}],
#              '1292': [{'utc_date': datetime.datetime(2018, 1, 7, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 22.18428317,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 9, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 3.011938833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 10, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 35.984489,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 129.5579277,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 35.83072233,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 6.636142333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 0}],
#              '1299': [{'utc_date': datetime.datetime(2018, 2, 5, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 6, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 113.7911188,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 2, 7, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 4.198808,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 1}],
#              '1303': [{'utc_date': datetime.datetime(2018, 4, 8, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 9, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0}],
#              '1305': [{'utc_date': datetime.datetime(2018, 5, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 2.056223333,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 5, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 7.7152505,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 5, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0}]})

# %%
# How many minutes did each student spend on the website total?
def sum_records(dataset, column):
    new_data = dict()
    for k, v in dataset.items():
        sum_ = 0
        for r in v:
            sum_ += r[column]
        new_data[k] = sum_
    return new_data
minutes_per_account = sum_records(engagements_grouped_by_account, 'total_minutes_visited')

# %%
minutes_per_account
# Out:
# {'3': 1023.5579746999999,
#  '5': 370.82494396,
#  '15': 1071.12533757,
#  '18': 155.1361575,
#  '19': 0.0,
#  '24': 943.1881172000001,
#  '25': 0.0,
#  '31': 247.27557963999996,
#  '34': 138.1789523,
#  '42': 174.30704300000002,
#  '43': 88.822038,
#  '44': 731.72366783,
#  '45': 979.7454166629999,
#  '51': 0.0,
#  '52': 3.227523833,
#  '53': 43.53851617,
#  '57': 750.894147533,
#  '60': 0.0,
#  '62': 293.3831222,
#  '64': 589.58194586,
#  '65': 422.27366,
#  '67': 1123.02533437,
#  '69': 0.0,
#  '72': 883.9906950330001,
#  '74': 90.48065633,
#  '76': 17.658779,
#  '78': 6.609209333,
#  '79': 416.495983833,
#  '85': 500.49217067,
#  '88': 106.16380783,
#  '90': 4.842514,
#  '91': 70.37317134,
#  '92': 715.4277596699999,
#  '93': 932.7172561699999,
#  '97': 494.84799353,
#  '98': 531.4097201300001,
#  '99': 425.60350947,
#  '101': 188.92038351,
#  '105': 573.58079867,
#  '106': 535.168407333,
#  '108': 164.270890837,
#  '110': 1403.143966737,
#  '111': 169.1595922,
#  '113': 139.57379017,
#  '119': 103.90436599,
#  '123': 0.0,
#  '130': 0.0,
#  '132': 1428.3456270000001,
#  '134': 1098.6832576400002,
#  '136': 66.30446384,
#  '138': 46.42543033,
#  '140': 202.6228267,
#  '141': 544.9926586,
#  '142': 505.63867662999996,
#  '143': 405.02286753,
#  '147': 416.49688996,
#  '148': 0.0,
#  '150': 486.24643833700003,
#  '151': 969.1894240600001,
#  '153': 116.8988095,
#  '157': 10.884649667,
#  '159': 18.44071917,
#  '160': 1011.9525945299999,
#  '161': 531.8882432099999,
#  '165': 1083.22753966,
#  '168': 1198.3499316,
#  '169': 223.6821162,
#  '170': 586.70428494,
#  '171': 2183.9339814,
#  '174': 472.61704748999995,
#  '178': 783.3383064,
#  '179': 967.46286586,
#  '180': 234.47278604000002,
#  '181': 166.14326012700002,
#  '185': 0.0,
#  '187': 743.655930133,
#  '190': 353.05917586000004,
#  '191': 28.868115997,
#  '193': 0.0,
#  '197': 931.3076662,
#  '203': 620.4744591699999,
#  '208': 356.77551814000003,
#  '217': 657.39103014,
#  '220': 346.78228750000005,
#  '221': 178.70479886999996,
#  '227': 548.49517273,
#  '229': 131.7264965,
#  '243': 46.60514067,
#  '251': 357.8209291,
#  '253': 465.4912042,
#  '256': 0.0,
#  '258': 748.13000253,
#  '259': 832.42184273,
#  '261': 0.0,
#  '263': 34.281020330000004,
#  '264': 110.09569266,
#  '265': 419.7968294,
#  '268': 314.33318003,
#  '270': 1123.238648,
#  '272': 1207.3723326629997,
#  '279': 375.05861866,
#  '284': 283.2611105,
#  '285': 183.175982167,
#  '289': 1092.578964797,
#  '293': 566.77326963,
#  '306': 6.61027,
#  '315': 952.1811420700001,
#  '316': 1825.6310638700004,
#  '321': 6.395196833,
#  '322': 0.0,
#  '323': 579.60225253,
#  '329': 89.68924583,
#  '334': 9.553760833,
#  '335': 947.24981713,
#  '338': 0.0,
#  '339': 0.0,
#  '343': 443.5831058,
#  '347': 104.97653,
#  '348': 445.67912980299997,
#  '361': 1053.7764164300002,
#  '362': 58.315108499999994,
#  '366': 23.551663167,
#  '367': 257.3663085,
#  '378': 0.0,
#  '386': 0.0,
#  '388': 147.8970597,
#  '394': 990.7801981700002,
#  '397': 261.91549584,
#  '402': 81.871438503,
#  '404': 737.44397104,
#  '407': 621.88870587,
#  '408': 59.77253067,
#  '410': 1007.8260931,
#  '411': 0.0,
#  '412': 108.9097063,
#  '413': 578.95028613,
#  '415': 183.21106814,
#  '416': 934.515744067,
#  '418': 86.78249267,
#  '419': 26.205425502999997,
#  '423': 0.0,
#  '426': 0.0,
#  '427': 413.54201817,
#  '429': 0.0,
#  '431': 77.97422683,
#  '434': 832.77642093,
#  '439': 278.86463337,
#  '440': 86.82050367,
#  '441': 1360.78769464,
#  '442': 383.48329069700003,
#  '444': 0.0,
#  '447': 291.0635962,
#  '458': 121.39381849699998,
#  '460': 1427.54662863,
#  '465': 260.92380287,
#  '467': 210.01318516999999,
#  '473': 0.0,
#  '474': 285.75573753000003,
#  '477': 793.77720249,
#  '480': 0.0,
#  '483': 869.7483835,
#  '499': 440.401314,
#  '500': 89.3707275,
#  '504': 388.7726185,
#  '505': 892.60699383,
#  '507': 63.843047333,
#  '512': 113.02499486699999,
#  '514': 62.848290659999996,
#  '520': 109.51497699999999,
#  '521': 406.04536986,
#  '523': 0.0,
#  '524': 85.26222933,
#  '525': 0.0,
#  '528': 514.0743979700001,
#  '529': 334.79837916699995,
#  '532': 505.55668749999995,
#  '534': 826.3571918700001,
#  '541': 20.879544832999997,
#  '544': 1421.7436063300001,
#  '547': 0.0,
#  '549': 124.2423835,
#  '550': 18.95128533,
#  '557': 0.0,
#  '558': 1334.00295304,
#  '563': 21.972605,
#  '564': 766.53773037,
#  '569': 1603.15193103,
#  '571': 312.22133734,
#  '576': 1366.5670150370001,
#  '577': 120.55847800299998,
#  '580': 851.429489267,
#  '583': 843.5311485300001,
#  '584': 0.0,
#  '587': 181.354424837,
#  '589': 168.39389986700002,
#  '590': 71.15551016,
#  '591': 0.0,
#  '597': 1158.3549946,
#  '599': 0.0,
#  '601': 267.874047797,
#  '602': 615.9597957,
#  '606': 456.33328183,
#  '610': 873.26167336,
#  '611': 382.930370467,
#  '612': 52.91365067,
#  '618': 513.81269814,
#  '622': 396.82058732999997,
#  '623': 230.7043745,
#  '624': 1197.02408723,
#  '626': 95.12250383,
#  '630': 537.7439134900001,
#  '631': 237.76465218,
#  '634': 324.29165179999995,
#  '636': 185.39436433,
#  '637': 89.05729567,
#  '639': 416.14186616999996,
#  '640': 0.0,
#  '641': 340.7062775,
#  '643': 218.9373798,
#  '645': 1122.85546837,
#  '649': 700.47435977,
#  '650': 114.84451633,
#  '651': 1460.3119036700002,
#  '655': 333.60102137,
#  '657': 0.0,
#  '660': 225.80730217,
#  '661': 92.55472316,
#  '666': 254.5694942,
#  '667': 144.12431733,
#  '669': 22.73084533,
#  '670': 454.2731635,
#  '671': 162.016680833,
#  '678': 100.0702155,
#  '682': 25.243540000000003,
#  '690': 159.93331549700002,
#  '692': 16.604203,
#  '693': 0.0,
#  '696': 666.3290910299999,
#  '697': 88.1119545,
#  '698': 70.974336167,
#  '702': 0.0,
#  '704': 0.0,
#  '705': 0.0,
#  '706': 1467.2371881000001,
#  '709': 88.0103965,
#  '710': 3.561991333,
#  '712': 253.23675753,
#  '713': 139.060529,
#  '718': 0.0,
#  '719': 9.4907925,
#  '720': 449.5952606370001,
#  '722': 29.9067615,
#  '726': 21.12844967,
#  '729': 0.0,
#  '730': 41.7199715,
#  '732': 219.92606669999998,
#  '735': 0.0,
#  '736': 313.501810333,
#  '743': 0.0,
#  '744': 374.57610381,
#  '746': 846.66856726,
#  '752': 30.59517617,
#  '753': 116.6288768,
#  '756': 0.0,
#  '757': 449.79538263000006,
#  '759': 0.0,
#  '761': 100.063683333,
#  '762': 114.52385583,
#  '769': 135.6825435,
#  '776': 0.0,
#  '777': 199.31994916,
#  '778': 48.19741517,
#  '779': 4.2604045,
#  '780': 0.0,
#  '785': 4.786497167,
#  '786': 23.695871503,
#  '787': 0.0,
#  '792': 1589.158705,
#  '793': 0.0,
#  '796': 0.0,
#  '800': 203.85678250299998,
#  '801': 0.0,
#  '804': 22.73466567,
#  '808': 106.2993215,
#  '811': 1138.31770153,
#  '822': 27.94316733,
#  '823': 0.0,
#  '824': 260.470246496,
#  '825': 49.29607483,
#  '828': 392.68479187,
#  '829': 129.762569,
#  '831': 51.016355999999995,
#  '833': 2.380932333,
#  '835': 0.0,
#  '836': 0.0,
#  '839': 13.587055,
#  '844': 839.243589237,
#  '846': 32.68610117,
#  '855': 92.68960016,
#  '856': 0.0,
#  '857': 0.0,
#  '858': 260.948644837,
#  '859': 2.541221667,
#  '864': 53.1295885,
#  '866': 0.0,
#  '867': 0.0,
#  '868': 13.442560666999999,
#  '873': 30.2541315,
#  '877': 26.52309817,
#  '882': 0.0,
#  '896': 0.0,
#  '897': 22.08896567,
#  '900': 0.0,
#  '905': 108.98321334,
#  '906': 0.0,
#  '909': 63.3749175,
#  '912': 0.0,
#  '913': 72.9583085,
#  '916': 65.7383995,
#  '918': 21.086721,
#  '919': 693.4264896600001,
#  '923': 0.0,
#  '927': 125.446569167,
#  '932': 0.0,
#  '934': 5.03956,
#  '937': 222.16125416,
#  '938': 69.45209899999999,
#  '941': 2.999349667,
#  '948': 94.32375533,
#  '952': 194.51546903000002,
#  '954': 91.64868467000001,
#  '955': 240.59597452999998,
#  '956': 6.806882833,
#  '958': 0.0,
#  '965': 796.0860388,
#  '966': 26.584319333000003,
#  '969': 24.966902329999996,
#  '972': 96.11371283999999,
#  '976': 65.05270717,
#  '983': 0.0,
#  '984': 188.307856327,
#  '985': 46.494977,
#  '988': 61.420162,
#  '989': 0.0,
#  '1007': 0.0,
#  '1009': 0.0,
#  '1011': 164.936009491,
#  '1013': 4.3800225,
#  '1015': 100.326129003,
#  '1019': 75.87298200000001,
#  '1022': 23.549948167,
#  '1029': 3.508856667,
#  '1030': 218.55650866300002,
#  '1033': 959.95343761,
#  '1038': 0.0,
#  '1040': 12.98248983,
#  '1042': 45.5670335,
#  '1049': 37.853095,
#  '1052': 117.1958063,
#  '1053': 81.44155333,
#  '1054': 0.0,
#  '1055': 71.57364067,
#  '1058': 0.0,
#  '1060': 1768.5227493,
#  '1062': 366.31941634000003,
#  '1066': 0.0,
#  '1071': 0.0,
#  '1074': 0.0,
#  '1075': 90.6038805,
#  '1077': 152.2132672,
#  '1082': 51.1061375,
#  '1088': 0.0,
#  '1089': 102.89907667,
#  '1090': 0.0,
#  '1094': 464.47214951,
#  '1095': 30.09755267,
#  '1099': 108.88937200999999,
#  '1102': 0.0,
#  '1103': 0.0,
#  '1107': 73.62896584,
#  '1111': 0.0,
#  '1115': 0.0,
#  '1117': 0.0,
#  '1118': 89.38367816,
#  '1121': 20.215805333,
#  '1123': 12.65633967,
#  '1124': 0.0,
#  '1128': 55.827512667,
#  '1130': 278.31484216,
#  '1139': 321.751190867,
#  '1140': 208.498611167,
#  '1142': 0.0,
#  '1146': 105.577247997,
#  '1153': 679.80029763,
#  '1160': 2.704084833,
#  '1161': 87.81235717,
#  '1163': 80.21072266,
#  '1167': 1229.5553959630001,
#  '1170': 91.43698283,
#  '1174': 76.1418825,
#  '1175': 2.7094835,
#  '1178': 0.0,
#  '1183': 258.8492892,
#  '1188': 411.07007933,
#  '1189': 481.1140735,
#  '1194': 168.1376205,
#  '1198': 6.5907805,
#  '1199': 4.714764167,
#  '1200': 824.427983767,
#  '1201': 526.6600761,
#  '1202': 48.679263336999995,
#  '1204': 381.32434615999995,
#  '1205': 0.0,
#  '1207': 26.4703245,
#  '1208': 114.066953,
#  '1210': 430.78566787,
#  '1211': 3.564415833,
#  '1212': 0.0,
#  '1214': 12.822523,
#  '1215': 1360.7287002000003,
#  '1217': 32.0539045,
#  '1220': 118.30495933,
#  '1226': 0.0,
#  '1236': 6.864152333,
#  '1242': 49.1640855,
#  '1243': 62.91143633,
#  '1244': 53.59622567,
#  '1247': 84.73468383299999,
#  '1248': 3.509181833,
#  '1249': 31.995718997,
#  '1253': 0.0,
#  '1254': 187.32349033,
#  '1259': 97.98160567,
#  '1260': 0.0,
#  '1264': 2.017341333,
#  '1266': 0.0,
#  '1268': 11.33088867,
#  '1277': 0.0,
#  '1285': 32.42569817,
#  '1287': 0.0,
#  '1289': 5.456283333,
#  '1292': 233.20550336600002,
#  '1299': 117.9899268,
#  '1303': 0.0,
#  '1305': 9.771473833}

# %%
### HOMEWORK:

### Take a look at data and come up with 3 good questions and use some of the methods done in this 
### Jupyter Notebook to successfully answer the questions.


### sum of lessons_completed by each student
### How many students were active on website within the second week?
### How many minutes did each student spend online in the second week?

# %%
### sum of lessons_completed by each student
lessons_sum_total = sum_records(engagements_grouped_by_account,'lessons_completed')
lessons_sum_total
# Out:
# {'3': 8,
#  '5': 0,
#  '15': 1,
#  '18': 0,
#  '19': 0,
#  '24': 4,
#  '25': 0,
#  '31': 0,
#  '34': 1,
#  '42': 0,
#  '43': 0,
#  '44': 3,
#  '45': 3,
#  '51': 0,
#  '52': 0,
#  '53': 0,
#  '57': 3,
#  '60': 0,
#  '62': 1,
#  '64': 9,
#  '65': 3,
#  '67': 4,
#  '69': 0,
#  '72': 8,
#  '74': 0,
#  '76': 0,
#  '78': 0,
#  '79': 1,
#  '85': 1,
#  '88': 0,
#  '90': 0,
#  '91': 0,
#  '92': 4,
#  '93': 6,
#  '97': 2,
#  '98': 2,
#  '99': 3,
#  '101': 0,
#  '105': 0,
#  '106': 3,
#  '108': 0,
#  '110': 10,
#  '111': 1,
#  '113': 0,
#  '119': 0,
#  '123': 0,
#  '130': 0,
#  '132': 1,
#  '134': 6,
#  '136': 0,
#  '138': 0,
#  '140': 0,
#  '141': 2,
#  '142': 0,
#  '143': 1,
#  '147': 6,
#  '148': 0,
#  '150': 2,
#  '151': 7,
#  '153': 1,
#  '157': 0,
#  '159': 1,
#  '160': 4,
#  '161': 3,
#  '165': 2,
#  '168': 7,
#  '169': 1,
#  '170': 2,
#  '171': 6,
#  '174': 1,
#  '178': 7,
#  '179': 5,
#  '180': 0,
#  '181': 0,
#  '185': 0,
#  '187': 2,
#  '190': 1,
#  '191': 0,
#  '193': 0,
#  '197': 9,
#  '203': 2,
#  '208': 1,
#  '217': 2,
#  '220': 2,
#  '221': 1,
#  '227': 3,
#  '229': 0,
#  '243': 0,
#  '251': 1,
#  '253': 0,
#  '256': 0,
#  '258': 4,
#  '259': 4,
#  '261': 0,
#  '263': 0,
#  '264': 1,
#  '265': 3,
#  '268': 5,
#  '270': 9,
#  '272': 8,
#  '279': 1,
#  '284': 2,
#  '285': 0,
#  '289': 8,
#  '293': 4,
#  '306': 0,
#  '315': 5,
#  '316': 9,
#  '321': 0,
#  '322': 0,
#  '323': 3,
#  '329': 0,
#  '334': 0,
#  '335': 3,
#  '338': 0,
#  '339': 0,
#  '343': 2,
#  '347': 0,
#  '348': 3,
#  '361': 10,
#  '362': 0,
#  '366': 0,
#  '367': 1,
#  '378': 0,
#  '386': 0,
#  '388': 1,
#  '394': 2,
#  '397': 1,
#  '402': 0,
#  '404': 2,
#  '407': 4,
#  '408': 0,
#  '410': 3,
#  '411': 0,
#  '412': 0,
#  '413': 2,
#  '415': 0,
#  '416': 0,
#  '418': 0,
#  '419': 0,
#  '423': 0,
#  '426': 0,
#  '427': 3,
#  '429': 0,
#  '431': 0,
#  '434': 5,
#  '439': 0,
#  '440': 0,
#  '441': 8,
#  '442': 0,
#  '444': 0,
#  '447': 1,
#  '458': 0,
#  '460': 3,
#  '465': 1,
#  '467': 0,
#  '473': 0,
#  '474': 5,
#  '477': 1,
#  '480': 0,
#  '483': 0,
#  '499': 2,
#  '500': 0,
#  '504': 3,
#  '505': 4,
#  '507': 0,
#  '512': 0,
#  '514': 0,
#  '520': 0,
#  '521': 1,
#  '523': 0,
#  '524': 0,
#  '525': 0,
#  '528': 3,
#  '529': 2,
#  '532': 2,
#  '534': 5,
#  '541': 0,
#  '544': 6,
#  '547': 0,
#  '549': 1,
#  '550': 0,
#  '557': 0,
#  '558': 4,
#  '563': 0,
#  '564': 3,
#  '569': 14,
#  '571': 1,
#  '576': 4,
#  '577': 0,
#  '580': 2,
#  '583': 8,
#  '584': 0,
#  '587': 0,
#  '589': 0,
#  '590': 0,
#  '591': 0,
#  '597': 6,
#  '599': 0,
#  '601': 3,
#  '602': 1,
#  '606': 2,
#  '610': 4,
#  '611': 1,
#  '612': 0,
#  '618': 4,
#  '622': 1,
#  '623': 0,
#  '624': 1,
#  '626': 1,
#  '630': 2,
#  '631': 1,
#  '634': 2,
#  '636': 0,
#  '637': 0,
#  '639': 0,
#  '640': 0,
#  '641': 2,
#  '643': 0,
#  '645': 3,
#  '649': 8,
#  '650': 1,
#  '651': 9,
#  '655': 0,
#  '657': 0,
#  '660': 0,
#  '661': 0,
#  '666': 1,
#  '667': 0,
#  '669': 0,
#  '670': 5,
#  '671': 0,
#  '678': 0,
#  '682': 0,
#  '690': 1,
#  '692': 0,
#  '693': 0,
#  '696': 2,
#  '697': 0,
#  '698': 0,
#  '702': 0,
#  '704': 0,
#  '705': 0,
#  '706': 10,
#  '709': 1,
#  '710': 0,
#  '712': 0,
#  '713': 0,
#  '718': 0,
#  '719': 0,
#  '720': 1,
#  '722': 1,
#  '726': 0,
#  '729': 0,
#  '730': 0,
#  '732': 0,
#  '735': 0,
#  '736': 0,
#  '743': 0,
#  '744': 1,
#  '746': 4,
#  '752': 0,
#  '753': 0,
#  '756': 0,
#  '757': 0,
#  '759': 0,
#  '761': 0,
#  '762': 0,
#  '769': 0,
#  '776': 0,
#  '777': 1,
#  '778': 0,
#  '779': 0,
#  '780': 0,
#  '785': 0,
#  '786': 0,
#  '787': 0,
#  '792': 13,
#  '793': 0,
#  '796': 0,
#  '800': 1,
#  '801': 0,
#  '804': 0,
#  '808': 0,
#  '811': 9,
#  '822': 0,
#  '823': 0,
#  '824': 1,
#  '825': 0,
#  '828': 2,
#  '829': 0,
#  '831': 0,
#  '833': 0,
#  '835': 0,
#  '836': 0,
#  '839': 0,
#  '844': 6,
#  '846': 0,
#  '855': 0,
#  '856': 0,
#  '857': 0,
#  '858': 1,
#  '859': 0,
#  '864': 0,
#  '866': 0,
#  '867': 0,
#  '868': 0,
#  '873': 0,
#  '877': 0,
#  '882': 0,
#  '896': 0,
#  '897': 0,
#  '900': 0,
#  '905': 0,
#  '906': 0,
#  '909': 0,
#  '912': 0,
#  '913': 0,
#  '916': 1,
#  '918': 0,
#  '919': 5,
#  '923': 0,
#  '927': 1,
#  '932': 0,
#  '934': 0,
#  '937': 1,
#  '938': 0,
#  '941': 0,
#  '948': 1,
#  '952': 1,
#  '954': 0,
#  '955': 0,
#  '956': 0,
#  '958': 0,
#  '965': 3,
#  '966': 0,
#  '969': 0,
#  '972': 0,
#  '976': 0,
#  '983': 0,
#  '984': 0,
#  '985': 0,
#  '988': 0,
#  '989': 0,
#  '1007': 0,
#  '1009': 0,
#  '1011': 0,
#  '1013': 0,
#  '1015': 0,
#  '1019': 0,
#  '1022': 0,
#  '1029': 0,
#  '1030': 2,
#  '1033': 9,
#  '1038': 0,
#  '1040': 0,
#  '1042': 0,
#  '1049': 0,
#  '1052': 0,
#  '1053': 0,
#  '1054': 0,
#  '1055': 0,
#  '1058': 0,
#  '1060': 1,
#  '1062': 0,
#  '1066': 0,
#  '1071': 0,
#  '1074': 0,
#  '1075': 0,
#  '1077': 0,
#  '1082': 1,
#  '1088': 0,
#  '1089': 0,
#  '1090': 0,
#  '1094': 1,
#  '1095': 0,
#  '1099': 1,
#  '1102': 0,
#  '1103': 0,
#  '1107': 0,
#  '1111': 0,
#  '1115': 0,
#  '1117': 0,
#  '1118': 1,
#  '1121': 0,
#  '1123': 0,
#  '1124': 0,
#  '1128': 0,
#  '1130': 0,
#  '1139': 1,
#  '1140': 2,
#  '1142': 0,
#  '1146': 0,
#  '1153': 3,
#  '1160': 0,
#  '1161': 0,
#  '1163': 0,
#  '1167': 5,
#  '1170': 0,
#  '1174': 0,
#  '1175': 0,
#  '1178': 0,
#  '1183': 1,
#  '1188': 3,
#  '1189': 0,
#  '1194': 0,
#  '1198': 0,
#  '1199': 0,
#  '1200': 1,
#  '1201': 2,
#  '1202': 1,
#  '1204': 2,
#  '1205': 0,
#  '1207': 0,
#  '1208': 1,
#  '1210': 1,
#  '1211': 0,
#  '1212': 0,
#  '1214': 0,
#  '1215': 6,
#  '1217': 0,
#  '1220': 0,
#  '1226': 0,
#  '1236': 0,
#  '1242': 0,
#  '1243': 0,
#  '1244': 0,
#  '1247': 0,
#  '1248': 0,
#  '1249': 0,
#  '1253': 0,
#  '1254': 0,
#  '1259': 0,
#  '1260': 0,
#  '1264': 0,
#  '1266': 0,
#  '1268': 0,
#  '1277': 0,
#  '1285': 0,
#  '1287': 0,
#  '1289': 0,
#  '1292': 0,
#  '1299': 1,
#  '1303': 0,
#  '1305': 0}

# %%
### How many minutes did each student spend online in the second week?

engagements_grouped_by_account2 = compare(second_week_engagements, 'account_key')
engagements_grouped_by_account2
# Out:
# defaultdict(list,
#             {'3': [{'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 195.6512002,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 163.3229915,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 54.30447583,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 64.15618933,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 35.82657267,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '3',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 1,
#                'account_key': '3',
#                'has_visited': 0}],
#              '5': [{'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 41.06708733,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 122.3769065,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 68.20015,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 18, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 11.88067217,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 19, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 186.740929,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 20, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 28.76410567,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 21, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 94.20400417,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '5',
#                'has_visited': 1}],
#              '15': [{'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 87.75029717,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 587.2439063,
#                'lessons_completed': 3,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 6.965367,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 137.4352888,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#                'num_courses_visited': 3,
#                'total_minutes_visited': 371.424635,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 17, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 185.7349495,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 18, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 339.687984,
#                'lessons_completed': 2,
#                'projects_completed': 0,
#                'account_key': '15',
#                'has_visited': 1}],
#              '18': [{'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 27.30114783,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 53.21899617,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 13.11253867,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '18',
#                'has_visited': 1}],
#              '19': [{'utc_date': datetime.datetime(2018, 4, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 56.55037833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 4, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 34.25590933,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 4, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 102.9685185,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 4, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 35.084522,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 4, 18, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 22.47995783,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 4, 19, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 88.137208,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 4, 20, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 39.8960985,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '19',
#                'has_visited': 1}],
#              '24': [{'utc_date': datetime.datetime(2017, 12, 10, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 8.736263,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 236.8847333,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 39.60244083,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 35.55680617,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 86.8071045,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 113.4100872,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '24',
#                'has_visited': 0}],
#              '25': [{'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 25, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '25',
#                'has_visited': 0}],
#              '31': [{'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 30.3134645,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 81.01106083,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 8.415288,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 7.258413,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '31',
#                'has_visited': 1}],
#              '34': [{'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 11.12878267,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 18, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 14.42753567,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '34',
#                'has_visited': 0}],
#              '42': [{'utc_date': datetime.datetime(2018, 3, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 114.1109268,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 168.3019898,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 42.64761467,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 62.98351467,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '42',
#                'has_visited': 0}],
#              '43': [{'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 21, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 16.59693217,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 22, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 85.41988567,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '43',
#                'has_visited': 1}],
#              '44': [{'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 194.944491,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 69.84251017,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '44',
#                'has_visited': 0}],
#              '45': [{'utc_date': datetime.datetime(2017, 11, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 8.639657833,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 89.3987495,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 109.930419,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 11.21532433,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 49.899687,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '45',
#                'has_visited': 1}],
#              '51': [{'utc_date': datetime.datetime(2018, 3, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 23, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 4.6223855,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 3, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '51',
#                'has_visited': 0}],
#              '52': [{'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 20, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 75.02298783,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 21, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 140.1605813,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '52',
#                'has_visited': 1}],
#              '53': [{'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 116.4771052,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 25, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 70.00719633,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 26, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 119.2739945,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 27, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 28, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '53',
#                'has_visited': 0}],
#              '57': [{'utc_date': datetime.datetime(2017, 11, 18, 0, 0),
#                'num_courses_visited': 3,
#                'total_minutes_visited': 279.5711662,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 19, 0, 0),
#                'num_courses_visited': 3,
#                'total_minutes_visited': 101.1056048,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 20, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 57.92066083,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 21, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 245.9219273,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 22, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 120.1855905,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 11, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 11, 25, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 191.5896768,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '57',
#                'has_visited': 1}],
#              '60': [{'utc_date': datetime.datetime(2018, 1, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 25, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 26, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 27, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 28, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '60',
#                'has_visited': 0}],
#              '62': [{'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '62',
#                'has_visited': 0}],
#              '64': [{'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 243.078919,
#                'lessons_completed': 3,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '64',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 18, 0, 0),
#                'num_courses_visited': 2,
# ...
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1285',
#                'has_visited': 0}],
#              '1287': [{'utc_date': datetime.datetime(2018, 3, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 3, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1287',
#                'has_visited': 0}],
#              '1289': [{'utc_date': datetime.datetime(2017, 12, 11, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 12, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2017, 12, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1289',
#                'has_visited': 0}],
#              '1292': [{'utc_date': datetime.datetime(2018, 1, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 15, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 126.5581835,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 16, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 126.8129355,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 1, 19, 0, 0),
#                'num_courses_visited': 2,
#                'total_minutes_visited': 97.197744,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 20, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 58.486067,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 1, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1292',
#                'has_visited': 0}],
#              '1299': [{'utc_date': datetime.datetime(2018, 2, 12, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 4.198808,
#                'lessons_completed': 1,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 2, 13, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 14, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 2, 16, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 54.96075867,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 2, 17, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 48.64599417,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 2, 18, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 115.1408608,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 2, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1299',
#                'has_visited': 0}],
#              '1303': [{'utc_date': datetime.datetime(2018, 4, 15, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 16, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 17, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 18, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 4, 20, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1303',
#                'has_visited': 0}],
#              '1305': [{'utc_date': datetime.datetime(2018, 5, 19, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 20, 0, 0),
#                'num_courses_visited': 1,
#                'total_minutes_visited': 10.07422733,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 1},
#               {'utc_date': datetime.datetime(2018, 5, 21, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 22, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 23, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 24, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 25, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0},
#               {'utc_date': datetime.datetime(2018, 5, 26, 0, 0),
#                'num_courses_visited': 0,
#                'total_minutes_visited': 0.0,
#                'lessons_completed': 0,
#                'projects_completed': 0,
#                'account_key': '1305',
#                'has_visited': 0}]})

# %%
### How many students were active on website within the second week?
def engagements_within_second_week(date_joined, date_of_second_engagement):
    time_difference = date_of_second_engagement - date_joined
    if time_difference.days >= 7 and time_difference.days < 15:
        return True

for r in quality_engagements:
    if r['num_courses_visited'] > 0:
        r['has_visited'] = 1
    else:
        r['has_visited'] = 0

second_week_engagements = list()
for r in quality_engagements:
    if engagements_within_second_week(accounts_in_good_standing[r['account_key']], r['utc_date']):
        second_week_engagements.append(r)

# %%
print(f"{len(second_week_engagements)} engagements within the second week.")
# Out:
# 3443 engagements within the second week.
